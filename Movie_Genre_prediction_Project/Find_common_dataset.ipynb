# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_text = pd.read_csv("gdrive/MyDrive/Colab Notebooks/trainingSet.csv")
l=[]
for i,j in enumerate(data_text["imdbID"]):
  j=j[3:]
  data_text.loc[i,"imdbID"]=j
data_text.rename(columns = {'imdbID':'imdbId'}, inplace = True)
#data_text.astype({"imdbId",int})
data_text[['imdbId']] = data_text[['imdbId']].apply(pd.to_numeric)
print(data_text.dtypes)
print("Size of text data is ",data_text.shape)
data_text.head(5)
# Out:
# imdbId     int64
# Title     object
# Plot      object
# Genre1    object
# Genre2    object
# Genre3    object
# dtype: object
# Size of text data is  (4456, 6)
#    imdbId                        Title  ...      Genre2    Genre3
# 0  114709                    Toy Story  ...   Adventure    Comedy
# 1  113497                      Jumanji  ...   Adventure    Family
# 2  113228             Grumpier Old Men  ...     Romance       NaN
# 3  114885            Waiting to Exhale  ...       Drama   Romance
# 4  113041  Father of the Bride Part II  ...      Family   Romance
#
# [5 rows x 6 columns]

# %%
data_poster = pd.read_csv("gdrive/MyDrive/Colab Notebooks/MovieGenre.csv",encoding='ISO-8859-1')
print(data_poster.dtypes)
print("Size of text data is ",data_poster.shape)
data_poster.head(5)
# Out:
# imdbId          int64
# Imdb Link      object
# Title          object
# IMDB Score    float64
# Genre          object
# Poster         object
# dtype: object
# Size of text data is  (40108, 6)
#    imdbId  ...                                             Poster
# 0  114709  ...  https://images-na.ssl-images-amazon.com/images...
# 1  113497  ...  https://images-na.ssl-images-amazon.com/images...
# 2  113228  ...  https://images-na.ssl-images-amazon.com/images...
# 3  114885  ...  https://images-na.ssl-images-amazon.com/images...
# 4  113041  ...  https://images-na.ssl-images-amazon.com/images...
#
# [5 rows x 6 columns]

# %%
df = pd.merge(data_text, data_poster, on='imdbId', how='inner')
df = df.drop(['Genre1','Genre2','Genre3','Title_y','IMDB Score','Imdb Link'],axis=1)
print("Length of common dataset is ",df.shape)
df.to_csv("gdrive/MyDrive/Colab Notebooks/Intersect_dataset.csv")
df.head(5)
# Out:
# Length of common dataset is  (4596, 5)
#    imdbId  ...                                             Poster
# 0  114709  ...  https://images-na.ssl-images-amazon.com/images...
# 1  113497  ...  https://images-na.ssl-images-amazon.com/images...
# 2  113228  ...  https://images-na.ssl-images-amazon.com/images...
# 3  114885  ...  https://images-na.ssl-images-amazon.com/images...
# 4  113041  ...  https://images-na.ssl-images-amazon.com/images...
#
# [5 rows x 5 columns]

# %%
l=[]
for i,j in enumerate(data_poster["imdbId"]):
  for i1,j1 in enumerate(data_text["imdbId"]):
    if j==j1:
      #print(j)
      l.append(j)
print("Common movies are ",len(l))
# Out:
# Common movies are  4596
